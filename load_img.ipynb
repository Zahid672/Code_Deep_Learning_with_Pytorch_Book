# %%
import torch
import numpy as np
import imageio

# %% [markdown]
# imageio module is used for loading image

# %%
img_array = imageio.imread('data/p1ch4/image-dog/bobby.jpg')
img_array.shape
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32940\3860481131.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_array = imageio.imread('data/p1ch4/image-dog/bobby.jpg')
# (720, 1280, 3)

# %%
img = torch.from_numpy(img_array)
out = img.permute(2, 0, 1)
out.shape
# Out:
# torch.Size([3, 720, 1280])

# %%
batch = 3
batch = torch.zeros(batch, 3, 256, 256, dtype=torch.uint8)
batch.shape
# Out:
# torch.Size([3, 3, 256, 256])

# %%
import os

data_dir = 'data/p1ch4/image-cats'
filenames = [name for name in os.listdir(data_dir) 
             if os.path.splitext(name)[-1] == '.png']
for i, filename in enumerate(filenames):
    img_arr = imageio.imread(os.path.join(data_dir, filename))
    img_t = torch.from_numpy(img_arr)
    img_t = img_t.permute(2, 0, 1)
    batch[i] = img_t
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32940\4185856128.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_arr = imageio.imread(os.path.join(data_dir, filename))

# %%
batch = batch.float()
batch /= 255.0

# %%
n_channels = batch.shape[1]
print(f'Number of channels: {n_channels}')
print(f'Batch shape: {batch.shape}')
print(f'Batch data type: {batch.dtype}')
for c in range(n_channels):
    mean = torch.mean(batch[:, c])
    std = torch.std(batch[:,c])
    print(f'Channel {c}: mean = {mean.item()}, std = {std.item()}')
    batch[:, c] = (batch[:, c] - mean) / std
# Out:
# Number of channels: 3
# Batch shape: torch.Size([3, 3, 256, 256])
# Batch data type: torch.float32
# Channel 0: mean = 0.5799327492713928, std = 0.22118069231510162
# Channel 1: mean = 0.4493196904659271, std = 0.20676465332508087
# Channel 2: mean = 0.35544052720069885, std = 0.1930793672800064
