# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
import imageio

dir_path = "data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_array = imageio.volread(dir_path, 'DICOM')
vol_array.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%28/99 files (28.3%58/99 files (58.6%88/99 files (88.9%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 99/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_array).float()
vol = vol.unsqueeze(0)

vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
import matplotlib.pyplot as plt

plt.imshow(vol_array[50])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.imshow(vol_array[50])
#
# ModuleNotFoundError: No module named 'matplotlib'
